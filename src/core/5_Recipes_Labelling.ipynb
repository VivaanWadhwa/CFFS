# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ***
#
# ## Part V: Labelling Recipes

# %% [markdown]
# ## Set up and Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import os
from configparser import ConfigParser

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ## Set Baselines

# %% [markdown]
# Make sure to run ```Label_Baseline_Calculation/baseline_OK.ipynb``` if there is a change in the baseline calculation or if a new parameter is added, update accordingly.

# %%
config = ConfigParser()
config.read("data/Misc/data_for_calculating_baseline/baseline.ini")

overall_baseline = float(config["baseline"]["GHG_baseline"])
fifty_cutoff = overall_baseline/2

GHG_baseline = float(config["baseline"]["GHG_baseline"])
nitrogen_baseline = float(config["baseline"]["nitrogen_baseline"])
water_baseline = float(config["baseline"]["water_baseline"])
land_baseline = float(config["baseline"]["land_baseline"])
print(GHG_baseline,nitrogen_baseline,water_baseline,land_baseline)
# Out:
# 364.61114734025256 4.428944853430558 1320.569404551064 0.8534548672606304

# %%
# CHANGE THIS AS NEEDED:
# restaurant_name = "OK24-25"
restaurant_name = "Gather24-25"
# restaurant_name = "Totem24-25"
# restaurant_name = "HARVEST_FESTIVAL"

# %%
def create_ghg_label(label):
    # determine the GHG label based on the given label value and predefined cutoffs
    if label > overall_baseline:
        # if the label value is > than overall baseline, assign "Red" label
        return "Red"
    elif (label <= overall_baseline) & (label > fifty_cutoff):
        # if the label value is between overall baseline and fifty_cutoff, assign "Yellow" label
        return "Yellow"
    elif label <= fifty_cutoff:
        # if the label value is less than or equal to the fifty_cutoff, assign "Green" label
        return "Green"

# %%
def create_results_all_factors(df):
    # create a Combined Label based on different factors for each row in the DataFrame
    df["Combined Label"] = ""

    # add another parameter: n so that change the number of factors instead of multiplying by 3

    def calculate_all_factors(ghg, nitrogen, water, land):
        # calculate the combined label value based on the given factors
        weighted_ghg = ghg / (4 * GHG_baseline)
        weighted_nitrogen = nitrogen / (4 * nitrogen_baseline)
        weighted_water = water / (4 * water_baseline)

        # most recently added
        weighted_land = land / (4 * land_baseline)

        return weighted_ghg + weighted_nitrogen + weighted_water + weighted_land


    for ind, row in df.iterrows():
        # iterate over each row in the DataFrame and calculate the combined label
        label = calculate_all_factors(row["GHG Emission (g) / 100g"], row["N lost (g) / 100g"],
                                      row["Stress-Weighted Water Use (L) / 100g"],
                                      row['Land Use (m^2) / 100g'])

        if label <= 0.5:
            # if the label value is less than or equal to 0.5, assign "Green" label
            df.loc[ind, "Combined Label"] = "Green"
        elif label >= 1:
            # if the label value is greater than or equal to 1, assign "Red" label
            df.loc[ind, "Combined Label"] = "Red"
        elif (label > 0.5) or (label < 1):
            # if the label value is between 0.5 and 1, assign "Yellow" label
            df.loc[ind, "Combined Label"] = "Yellow"
    return df

# %%
def add_menu_names(df, dict):
    # add menu names to the DataFrame based on a dictionary
    df["Displayed Name"] = ""
    menu_name = list(dict.keys())
    menu_ID = list(dict.values())
    for ind, row in df.iterrows():
        searchID = row["ProdId"]
        if searchID in menu_ID:
            # if the product ID is found in the menu_ID list, retrieve the corresponding name
            position = menu_ID.index(searchID)
            name = menu_name[position]
            df.loc[ind, "Displayed Name"] = name
        else:
            continue
    name_col = df.pop("Displayed Name")
    df.insert(0, "Displayed Name", name_col)
    df = df.dropna(subset=["Displayed Name"])

    df_temp = df["Displayed Name"].str.split("|", expand=True)
    df["Category"] = df_temp[0]
    df["Displayed Name"] = df_temp[1]
    name_col2 = df.pop("Category")
    df.insert(0, "Category", name_col2)
    # returns the modified DataFrame with the added "Category" and "Displayed Name" columns
    return df

# %%
def create_final_counts(df):
    # create final counts of GHG and combined labels from DataFrame

    # count the occurrences of GHG Only labels
    ghg_red = df["GHG Only Label"].value_counts()["Red"]
    ghg_yellow = df["GHG Only Label"].value_counts()["Yellow"]
    ghg_green = df["GHG Only Label"].value_counts()["Green"]
    # count the occurrences of Combined labels
    all_red = df["Combined Label"].value_counts()["Red"]
    all_yellow = df["Combined Label"].value_counts()["Yellow"]
    all_green = df["Combined Label"].value_counts()["Green"]
    print(all_red, all_yellow, all_green)
    # create a dictionary to store the label counts
    data = {"GHG Label Counts": [ghg_red, ghg_yellow, ghg_green],
            "Combined Label Counts": [all_red, all_yellow, all_green]}
    # create a DataFrame from the label counts data and return it
    results = pd.DataFrame(data, index=["Red", "Yellow", "Green"])
    return results

# %%
def create_visualizations(df):
    df.reset_index(inplace=True)
    df = df.rename(columns={"index": "Color"})
    sns.set_theme(style="darkgrid")
    palette = {"Green": "tab:green", "Red": "tab:red", "Yellow": "tab:orange", "Sum": "tab:blue"}
    fig, axes = plt.subplots(1, 2, figsize=(7, 4), sharex=False, sharey=True)
    fig.suptitle("Emission Label Counts")
    ax1 = sns.barplot(data=df, x=df["Color"], y=df["GHG Label Counts"], ax=axes[0], palette=palette)
    ax1.set_title("GHG Emission Label")
    ax1.set_ylabel("Counts")
    ax1.set_xlabel("")
    ax2 = sns.barplot(data=df, x=df["Color"], y=df["Combined Label Counts"], ax=axes[1], palette=palette)
    ax2.set_title("Combined Emissions Label")
    ax2.set_ylabel("")
    ax2.set_xlabel("")
    fig.title = "Color Comparison"
    ax1.set_title = "GHG Emission Label Counts"
    ax2.set_title = "Combined Emissions Label Counts"
    ax2.set_ylabel = ""
    for ax in [ax1, ax2]:
        for i in ax.containers:
            ax.bar_label(i, )
    plt.tight_layout()
    plt.savefig(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/" + restaurant_name + "Summary_fig.png")
    plt.show()

# %%
def create_category_true(df):
    # create category columns for True values in the DataFrame

    # create empty columns for each category
    df["RED"] = ""
    df["YELLOW"] = ""
    df["GREEN"] = ""
    # iterate over each row in the DataFrame
    for ind, row in df.iterrows():
        # Check the value of the Combined Label column and assign "TRUE" to the corresponding category column
        if row["Combined Label"] == "Red":
            df.loc[ind, "RED"] = "TRUE"
        if row["Combined Label"] == "Yellow":
            df.loc[ind, "YELLOW"] = "TRUE"
        if row["Combined Label"] == "Green":
            df.loc[ind, "GREEN"] = "TRUE"
    # adds category columns for True values based on the Combined Label column
    return df

# %%
products = pd.read_csv(os.path.join(os.getcwd(), "data", "final", "Recipes Footprints.csv"))

# %%
final = products.copy()
final
# Out:
#       ProdId                    Description   SalesGroup  Weight (g)  \
# 0    R-73669  DEL|smoothie| mango pineapple  GV - DELISH      350.00
# 1    R-56613   DEL|Smoothie|Almonds forever  GV - DELISH       71.00
# 2    R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH        1.00
# 3    R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH        1.00
# 4    R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH      365.00
# ..       ...                            ...          ...         ...
# 406  P-72728   PREP|Lemongrass Pork Chop|SL          NaN   130000.00
# 407  P-32244        SAUCE|Chipotle Mayo|GRL         PREP     1000.00
# 408  P-73472  PREP|SALAD|Tomato CucMint|MED          NaN     6000.00
# 409  P-73266     SALAD|QuinoaTabbouleh|MED*         PREP     2800.00
# 410  I-71938            FRIES 3/8IN*CRINKLE      PRODUCE     2267.96
#
#      GHG Emission (g)    N lost (g)  Land Use (m^2)  \
# 0        7.715136e+01      0.375085        0.148062
# 1        3.246587e+02      1.122366        0.675339
# 2        7.806481e-01      0.004219        0.001520
# 3        4.520079e+00      0.018895        0.003462
# 4        1.694326e+02      0.488466        0.549266
# ..                ...           ...             ...
# 406      1.385712e+06  18655.025000     2962.371000
# 407      3.107182e+03      0.612000       15.102200
# 408      3.146048e+03     38.538561        6.918892
# 409      2.888544e+03     17.897109        8.409705
# 410      9.003801e+02  11339.800000        1.179339
#
#      Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                          0.59                           1.92
# 1                        101.87                        7213.85
# 2                          0.20                          11.70
# 3                          0.77                          32.31
# 4                          2.19                         128.61
# ..                          ...                            ...
# 406                   253705.81                     7603131.92
# 407                        5.77                         173.35
# 408                      366.48                       16565.10
# 409                      453.94                       11150.68
# 410                        5.90                         177.58
#
#      GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                      22.04               0.11
# 1                     457.27               1.58
# 2                      78.06               0.42
# 3                     452.01               1.89
# 4                      46.42               0.13
# ..                       ...                ...
# 406                  1065.93              14.35
# 407                   310.72               0.06
# 408                    52.43               0.64
# 409                   103.16               0.64
# 410                    39.70             500.00
#
#      Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                 0.17                                  0.55
# 1                               143.48                              10160.35
# 2                                20.00                               1170.00
# 3                                77.00                               3231.00
# 4                                 0.60                                 35.24
# ..                                 ...                                   ...
# 406                             195.16                               5848.56
# 407                               0.58                                 17.34
# 408                               6.11                                276.08
# 409                              16.21                                398.24
# 410                               0.26                                  7.83
#
#      Land Use (m^2) / 100g
# 0                     0.04
# 1                     0.95
# 2                     0.15
# 3                     0.35
# 4                     0.15
# ..                     ...
# 406                   2.28
# 407                   1.51
# 408                   0.12
# 409                   0.30
# 410                   0.05
#
# [411 rows x 14 columns]

# %%
final["GHG Only Label"] = final["GHG Emission (g) / 100g"].apply(lambda x: create_ghg_label(x))
final
# Out:
#       ProdId                    Description   SalesGroup  Weight (g)  \
# 0    R-73669  DEL|smoothie| mango pineapple  GV - DELISH      350.00
# 1    R-56613   DEL|Smoothie|Almonds forever  GV - DELISH       71.00
# 2    R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH        1.00
# 3    R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH        1.00
# 4    R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH      365.00
# ..       ...                            ...          ...         ...
# 406  P-72728   PREP|Lemongrass Pork Chop|SL          NaN   130000.00
# 407  P-32244        SAUCE|Chipotle Mayo|GRL         PREP     1000.00
# 408  P-73472  PREP|SALAD|Tomato CucMint|MED          NaN     6000.00
# 409  P-73266     SALAD|QuinoaTabbouleh|MED*         PREP     2800.00
# 410  I-71938            FRIES 3/8IN*CRINKLE      PRODUCE     2267.96
#
#      GHG Emission (g)    N lost (g)  Land Use (m^2)  \
# 0        7.715136e+01      0.375085        0.148062
# 1        3.246587e+02      1.122366        0.675339
# 2        7.806481e-01      0.004219        0.001520
# 3        4.520079e+00      0.018895        0.003462
# 4        1.694326e+02      0.488466        0.549266
# ..                ...           ...             ...
# 406      1.385712e+06  18655.025000     2962.371000
# 407      3.107182e+03      0.612000       15.102200
# 408      3.146048e+03     38.538561        6.918892
# 409      2.888544e+03     17.897109        8.409705
# 410      9.003801e+02  11339.800000        1.179339
#
#      Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                          0.59                           1.92
# 1                        101.87                        7213.85
# 2                          0.20                          11.70
# 3                          0.77                          32.31
# 4                          2.19                         128.61
# ..                          ...                            ...
# 406                   253705.81                     7603131.92
# 407                        5.77                         173.35
# 408                      366.48                       16565.10
# 409                      453.94                       11150.68
# 410                        5.90                         177.58
#
#      GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                      22.04               0.11
# 1                     457.27               1.58
# 2                      78.06               0.42
# 3                     452.01               1.89
# 4                      46.42               0.13
# ..                       ...                ...
# 406                  1065.93              14.35
# 407                   310.72               0.06
# 408                    52.43               0.64
# 409                   103.16               0.64
# 410                    39.70             500.00
#
#      Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                 0.17                                  0.55
# 1                               143.48                              10160.35
# 2                                20.00                               1170.00
# 3                                77.00                               3231.00
# 4                                 0.60                                 35.24
# ..                                 ...                                   ...
# 406                             195.16                               5848.56
# 407                               0.58                                 17.34
# 408                               6.11                                276.08
# 409                              16.21                                398.24
# 410                               0.26                                  7.83
#
#      Land Use (m^2) / 100g GHG Only Label
# 0                     0.04          Green
# 1                     0.95            Red
# 2                     0.15          Green
# 3                     0.35            Red
# 4                     0.15          Green
# ..                     ...            ...
# 406                   2.28            Red
# 407                   1.51         Yellow
# 408                   0.12          Green
# 409                   0.30          Green
# 410                   0.05          Green
#
# [411 rows x 15 columns]

# %%
final = create_results_all_factors(final)
final
# Out:
#       ProdId                    Description   SalesGroup  Weight (g)  \
# 0    R-73669  DEL|smoothie| mango pineapple  GV - DELISH      350.00
# 1    R-56613   DEL|Smoothie|Almonds forever  GV - DELISH       71.00
# 2    R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH        1.00
# 3    R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH        1.00
# 4    R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH      365.00
# ..       ...                            ...          ...         ...
# 406  P-72728   PREP|Lemongrass Pork Chop|SL          NaN   130000.00
# 407  P-32244        SAUCE|Chipotle Mayo|GRL         PREP     1000.00
# 408  P-73472  PREP|SALAD|Tomato CucMint|MED          NaN     6000.00
# 409  P-73266     SALAD|QuinoaTabbouleh|MED*         PREP     2800.00
# 410  I-71938            FRIES 3/8IN*CRINKLE      PRODUCE     2267.96
#
#      GHG Emission (g)    N lost (g)  Land Use (m^2)  \
# 0        7.715136e+01      0.375085        0.148062
# 1        3.246587e+02      1.122366        0.675339
# 2        7.806481e-01      0.004219        0.001520
# 3        4.520079e+00      0.018895        0.003462
# 4        1.694326e+02      0.488466        0.549266
# ..                ...           ...             ...
# 406      1.385712e+06  18655.025000     2962.371000
# 407      3.107182e+03      0.612000       15.102200
# 408      3.146048e+03     38.538561        6.918892
# 409      2.888544e+03     17.897109        8.409705
# 410      9.003801e+02  11339.800000        1.179339
#
#      Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                          0.59                           1.92
# 1                        101.87                        7213.85
# 2                          0.20                          11.70
# 3                          0.77                          32.31
# 4                          2.19                         128.61
# ..                          ...                            ...
# 406                   253705.81                     7603131.92
# 407                        5.77                         173.35
# 408                      366.48                       16565.10
# 409                      453.94                       11150.68
# 410                        5.90                         177.58
#
#      GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                      22.04               0.11
# 1                     457.27               1.58
# 2                      78.06               0.42
# 3                     452.01               1.89
# 4                      46.42               0.13
# ..                       ...                ...
# 406                  1065.93              14.35
# 407                   310.72               0.06
# 408                    52.43               0.64
# 409                   103.16               0.64
# 410                    39.70             500.00
#
#      Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                 0.17                                  0.55
# 1                               143.48                              10160.35
# 2                                20.00                               1170.00
# 3                                77.00                               3231.00
# 4                                 0.60                                 35.24
# ..                                 ...                                   ...
# 406                             195.16                               5848.56
# 407                               0.58                                 17.34
# 408                               6.11                                276.08
# 409                              16.21                                398.24
# 410                               0.26                                  7.83
#
#      Land Use (m^2) / 100g GHG Only Label Combined Label
# 0                     0.04          Green          Green
# 1                     0.95            Red            Red
# 2                     0.15          Green          Green
# 3                     0.35            Red            Red
# 4                     0.15          Green          Green
# ..                     ...            ...            ...
# 406                   2.28            Red            Red
# 407                   1.51         Yellow         Yellow
# 408                   0.12          Green          Green
# 409                   0.30          Green          Green
# 410                   0.05          Green            Red
#
# [411 rows x 16 columns]

# %%
final.to_csv(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+".csv", 
             index=False)
final.to_excel(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+".xlsx", 
               sheet_name="Labels", index=False)

# %%
# CHANGE THE NAME AS NEEDED AS PER THE RESTAURANT:

OK_list = final.set_index('Description')['ProdId'].to_dict()
OK_list
# Out:
# {'DEL|smoothie| mango pineapple': 'R-73669',
#  'DEL|Smoothie|Almonds forever': 'R-56613',
#  'DEL|Smoothie|Banana Matcha ': 'R-44306',
#  'DEL|Smoothie|Blueberry Boost ': 'R-43697',
#  'DEL|Smoothie|Bna Almnd Buta': 'R-46074',
#  'DEL|Smoothie|C++': 'R-55185',
#  'DEL|Smoothie|Chocohlic ': 'R-44591',
#  'DEL|Smoothie|coconut mangoo': 'R-73662',
#  'DEL|Smoothie|Delish': 'R-36817',
#  'DEL|Smoothie|Green means go': 'R-56680',
#  'DEL|Smoothie|Hawaiian Sun': 'R-40466',
#  'DEL|Smoothie|Presso Espresso': 'R-73665',
#  'DEL|Smoothie|Rise & Shine': 'R-36763',
#  'DEL|smoothie|strawberry banana': 'R-73666',
#  'DEL|Smoothie|Strwbry Cupid': 'R-49036',
#  'DEL|Smoothie|tropical ': 'R-73663',
#  'DIM SUM|Bun|BBQ Pork (1)': 'R-14085',
#  'DIM SUM|Bun|Chicken (1)': 'R-37741',
#  'DIM SUM|Bun|Vegetable (1)': 'R-47286',
#  'DIM SUM|Dumplings (3)': 'R-49029',
#  'DIM SUM|Potstickers (3)': 'R-49030',
#  'DIM SUM|Wrap Sticky Rice (1)': 'R-37809',
#  'FF|Bibimbap Bowl|AAD': 'R-54202',
#  'FF|Bowl|Asparagus scramble|AAD': 'R-64951',
#  'FF|Bowl|Black Bean Break|AAD': 'R-27275',
#  'FF|Bowl|chilimiso scramble|AAD': 'R-65942',
#  'FF|Bowl|Curried Chickpea|AAD': 'R-32886',
#  'FF|BOWL|Dobanjiang Noodle|AAD ': 'R-43738',
#  'FF|Bowl|Fajita VEG|AAD': 'R-57179',
#  'FF|Bowl|Five Alarm|AAD': 'R-36666',
#  'FF|Bowl|Gather|AAD': 'R-36575',
#  'FF|Bowl|Kale|AAD': 'R-54039',
#  'FF|Bowl|Mediterranean|AAD': 'R-55057',
#  'FF|Bowl|OysterMushroom|AAD': 'R-64398',
#  'FF|Bowl|Poached Egg Zuc.|AAD': 'R-65761',
#  'FF|Bowl|Roasted squash|AAD': 'R-50333',
#  'FF|Bowl|Salsa scramble|AAD': 'R-65513',
#  'FF|Bowl|Thai Coconut|AAD': 'R-40621',
#  'FF|Bowl|White bean breaky|AAD': 'R-51215',
#  'FF|BowlEggplant miso|AAD': 'R-67295',
#  'FF|Brussel Sprout Pasta|AAD': 'R-56895',
#  'FF|Burger|lionsmane crunch|AAD': 'R-64698',
#  'FF|Falafel bowl|AAD': 'R-55942',
#  'FF|Omelette|3Cheese|AAD': 'R-70058',
#  'FF|Omelette|Mushroom&Ched|AAD': 'R-70095',
#  'FF|Omelette|Pepper&Onion|AAD': 'R-71818',
#  'FF|Omelette|Shitake Mozza|AAD': 'R-44732',
#  'FF|Omelette|SpinachFeta|AAD': 'R-70057',
#  'FF|Overnight oats|AppleCin|AAD': 'R-61853',
#  'FF|Overnight oats|Banana|AAD': 'R-61855',
#  'FF|Overnight Oats|BlackB|AAD': 'R-72313',
#  'FF|Overnight Oats|Blue|AAD': 'R-66411',
#  'FF|Overnight Oats|Matcha|AAD': 'R-73481',
#  'FF|Overnight Oats|Straw|AAD': 'R-69124',
#  'FF|Overnight Oats|Tiramisu|AAD': 'R-73482',
#  'FF|OvernightOats|Pineapple|AAD': 'R-73480',
#  'FF|Pasta|Artichoke Penne|AAD': 'R-47827',
#  'FF|Pasta|Duxcell Spaghetti|AAD': 'R-68821',
#  'FF|Pasta|Harvest Squash|AAD': 'R-58351',
#  'FF|Pasta|mush tortellini|AAD': 'R-71988',
#  'FF|Pasta|Ravioli butternut|AAD': 'R-61911',
#  'FF|Pasta|Spinach Avocado|AAD': 'R-36568',
#  'FF|Pasta|Tomato basil|AAD': 'R-55234',
#  'FF|Quesadilla|Breakfast|AAD': 'R-56509',
#  'FF|Ratatoullie|bowl|AAD': 'R-54608',
#  'FF|Risotto|Mushroom|Herbs&chee': 'R-47096',
#  'FF|Risotto|Primavera|AAD': 'R-55151',
#  'FF|Risotto|Squash|Herbs&cheese': 'R-55148',
#  'FF|Salad|UBC Power|AAD': 'R-36574',
#  'FF|Spaghetti Puttanesca|AAD': 'R-50694',
#  'FF|Tabbouleh Bowl|AAD': 'R-35461',
#  'FF|Toast|Beans On Toast|AAD': 'R-56719',
#  'FF|Toast|Bruscetta|AAD': 'R-61875',
#  'FF|Toast|Farm Veg toast|AAD': 'R-56718',
#  'FF|Toast|Mushroom toast|AAD': 'R-61874',
#  'FF|Toast|Shaved fennel|AAD': 'R-65943',
#  'FF|Toast|Smashed Avocado|AAD': 'R-36669',
#  'FF|Yaki Soba Miso Noodle|AAD': 'R-36552',
#  'FLX|Bao Shitake & Kimchi|AAD': 'R-44885',
#  'FLX|Bao|Bun|Crispy Tofu|AAD': 'R-73539',
#  'FLX|Bao|Bun|PickleEggplant|AAD': 'R-73591',
#  'FLX|Bao|Bun|Tamago|AAD': 'R-73549',
#  'FLX|Bao|Bun|Waygu|AAD': 'R-73526',
#  'FLX|Bao|Pork Belly|AAD': 'R-44883',
#  'FLX|Bao|Thai Chicken|AAD': 'R-40586',
#  'FLX|Beef Brisket|AAD ': 'R-61932',
#  'FLX|Butter chicken|AAD': 'R-56775',
#  'FLX|Butter tofu|AAD': 'R-57264',
#  'FLX|cauliflower steak 150g|AAD': 'R-61924',
#  'FLX|CheeseTortellinni|AAD': 'R-72100',
#  'FLX|Chickpea Vindaloo|AAD': 'R-56827',
#  'FLX|Fish Fritters|160g| AAD': 'R-61978',
#  'FLX|Garlic cheesey toast': 'R-62369',
#  'FLX|Greek Chicken Skewer|+2': 'R-62029',
#  'FLX|Laksa|eggplant Tofu|AAD': 'R-65254',
#  'FLX|Laksa|ling cod|AAD 100g': 'R-64446',
#  'FLX|Laksa|Salmon|AAD': 'R-45203',
#  'FLX|Palak Paneer|AAD': 'R-69621',
#  'FLX|Pasta Bar|Alfredo': 'R-56121',
#  'FLX|Pasta|Mac + Cheese|AAD': 'R-61943',
#  'FLX|Pho Beef Noodle|AAD': 'R-44766',
#  'FLX|Porchetta|150g|AAD': 'R-52676',
#  'FLX|Quiche|3 Cheese|AAD': 'R-26808',
#  'FLX|Quiche|Denver|AAD': 'R-51258',
#  'FLX|Quiche|Ham&Cheese|AAD': 'R-26809',
#  'FLX|Quiche|Mediterranean|AAD': 'R-71815',
#  'FLX|Quiche|Smoked Salmon|AAD': 'R-57034',
#  'FLX|Quiche|Spinach&Feta|AAD': 'R-62005',
#  'FLX|Shoyu Chicken|AAD': 'R-45153',
#  'FLX|Shoyu Salmon|AAD': 'R-69236',
#  'FLX|Shoyu tofu|AAD': 'R-61956',
#  'FLX|Side Naan|AAD': 'R-37051',
#  'FLX|Spicy Soy Salmon 100g|AAD': 'R-61967',
#  'FLX|Spicy Soy tofu 150g|AAD': 'R-62288',
#  'FLX|Stew beef one pot |AAD': 'R-47094',
#  'FLX|Tonkotsu Ramen|AAD': 'R-57280',
#  'FLX|Veg Lasagna 275g|AAD': 'R-28396',
#  'G&G|Cornbread|Ed': 'R-53835',
#  'GRL|Add|Spinach cooked': 'R-45468',
#  'GRL|Bacon Cheddar Dog|AAD': 'R-70604',
#  'GRL|BBQ Chicken Burger|AAD': 'R-71987',
#  'GRL|Benny |Avocado spinach|AAD': 'R-50312',
#  'GRL|Benny PulledPork|AAD': 'R-55646',
#  'GRL|Benny|Asparagus|AAD': 'R-62002',
#  'GRL|Benny|Crispy chicken|AAD': 'R-68109',
#  'GRL|Benny|fennel|AAD': 'R-68110',
#  'GRL|Benny|florentine|AAD': 'R-50515',
#  'GRL|Benny|Ham & mustard|AAD': 'R-62012',
#  'GRL|Benny|Salmon|AAD': 'R-61998',
#  'GRL|Big Burger|kimchiBacon|AAD': 'R-56157',
#  'GRL|Big Burger|Lumberjack|AAD': 'R-44655',
#  'GRL|BOWL|Asparagus poached egg': 'R-61824',
#  'GRL|Bowl|Gather & Run|AAD': 'R-44024',
#  'GRL|BOWL|Huevos Ranch J.E.|AAD': 'R-72498',
#  'GRL|Bowl|Professors|Breakfast|': 'R-44650',
#  'GRL|BOWL|White Bean|AAD': 'R-44316',
#  'GRL|Brocco fritters|AAD': 'R-68382',
#  'GRL|Burger|Adobo chicken|AAD': 'R-55424',
#  'GRL|Burger|Alumni Cheese|AAD': 'R-72157',
#  'GRL|Burger|Alumni|AAD': 'R-68378',
#  'GRL|Burger|Alumni|bacon cheese': 'R-36098',
#  'GRL|Burger|BombayTurkey|AAD': 'R-73195',
#  'GRL|Burger|Cod|AAD': 'R-69702',
#  'GRL|Burger|Jackfruit|AAD': 'R-53579',
#  'GRL|Burger|Lions maneBBQ|AAD': 'R-65248',
#  'GRL|Burger|lions maneGreek|AAD': 'R-69135',
#  'GRL|burger|Lionsmane Bfalo|AAD': 'R-69629',
#  'GRL|Burger|Portobello|AAD': 'R-61830',
#  'GRL|Burger|Salmon|AAD': 'R-44931',
#  'GRL|Burger|swiss chz|Pork|AAD': 'R-50118',
#  'GRL|Burger|Swiss Mushroom|AAD': 'R-70492',
#  'GRL|Burger|TurkeyParm|AAD': 'R-73194',
#  'GRL|Cauliflower Bites|AAD 160g': 'R-61982',
#  'GRL|Cauliflower Dog|AAD': 'R-53420',
#  'GRL|Cheese Burger Roll|SP': 'R-53471',
#  'GRL|Chick Wings|W/O Gluten|AAD': 'R-44779',
#  'GRL|Chicken Bahn Mi|AAD': 'R-70742',
#  'GRL|Chicken Burger|Buffalo|AAD': 'R-56137',
#  'GRL|Chicken Burger|Cajun|AAD': 'R-55469',
#  'GRL|Chicken Burger|Guaco bacon': 'R-28251',
#  'GRL|Chicken Burger|Maui|AAD': 'R-56454',
#  'GRL|Chicken Burger|Shoyu|AAD': 'R-45150',
#  'GRL|Chicken Burger|Teri|AAD': 'R-72077',
#  'GRL|ChickenBur|Thai Chili|AAD': 'R-43964',
#  'GRL|Chili Dog|AAD': 'R-52133',
#  'GRL|DB Cheese Bagel Melt|AAD': 'R-70292',
#  'GRL|Egg Any Style': 'R-38256',
#  'GRL|Egg|Scrambled|AAD': 'R-36654',
#  'GRL|English Muffin Sand|AAD': 'R-53788',
#  'GRL|French Toast (2) Special': 'R-53150',
#  'GRL|French Toast Banana |AAD': 'R-71966',
#  'GRL|French Toast Black|AAD': 'R-69126',
#  'GRL|French Toast Raz |AAD': 'R-68973',
#  'GRL|French Toast straw |AAD': 'R-49404',
#  'GRL|French Toast|BlueBerry|AAD': 'R-70675',
#  'GRL|French Toast|mangopin|AAD': 'R-70676',
#  'GRL|fries|Waffle|AAD ': 'R-72829',
#  'GRL|Grilled CheeGRse|B avo|AAD': 'R-50669',
#  'GRL|Grilled Cheese|Jalap|AAD': 'R-50668',
#  'GRL|Grilled Cheese|kimchi|AAD': 'R-68406',
#  'GRL|GrilledCheese|Classic|AAD': 'R-36139',
#  'GRL|GrilledCheese|Ham|AAD': 'R-70493',
#  'GRL|Ham&Cheese Scramble|AAD': 'R-70295',
#  'GRL|Herb&Vegetable|Hash|AAD': 'R-72133',
#  'GRL|Justegg|omellet': 'R-70016',
#  'GRL|Lions mane Burger|Cajn|AAD': 'R-69609',
#  'GRL|Mexi Scramble|AAD': 'R-70697',
#  'GRL|Pancakes|apple cin|AAD(1)': 'R-68108',
#  'GRL|Pancakes|Banana|AAD (1)': 'R-55513',
#  'GRL|Pancakes|Blackberry (2ea)': 'R-68119',
#  'GRL|Pancakes|Blueberry|AAD': 'R-36646',
#  'GRL|Pancakes|chocochip|AAD': 'R-70013',
#  'GRL|Pancakes|mangoPine|AAD': 'R-70674',
#  'GRL|Pancakes|Raseberry|AAD': 'R-72777',
#  'GRL|Pancakes|Strawberry|AAD ': 'R-68099',
#  'GRL|Plant base pepper dog|AAD': 'R-53419',
#  'GRL|Poutine|Classic|AAD': 'R-44775',
#  'GRL|Poutine|Jalepeno|AAD': 'R-57094',
#  'GRL|Poutine|Mushroom|AAD': 'R-44777',
#  'GRL|Poutine|Nacho|AAD': 'R-71891',
#  'GRL|Prima vera JustEgg|AAD': 'R-72497',
#  'GRL|Prima vera Scramble|AAD': 'R-70293',
#  'GRL|Pulled Pork Sandwich|AAD': 'R-71963',
#  'GRL|Salad|Baja|CHICKEN|AAD': 'R-64467',
#  'GRL|Salad|Spicy Caesar|AAD': 'R-57819',
#  'GRL|Sand|B.E.L.T.|AAD': 'R-45077',
#  'GRL|SAND|Bfast bacon & egg|AAD': 'R-71968',
#  'GRL|SAND|Bfast ham & egg|AAD': 'R-71967',
#  'GRL|Sand|Monte Cristo|AAD': 'R-56456',
#  'GRL|sand|Reuben|AAD': 'R-50491',
#  'GRL|SAND|Toad in Hole|AAD': 'R-73434',
#  'GRL|Sandwich|breakfast BLT|AAD': 'R-70679',
#  'GRL|Sandwich|Cubano|AAD': 'R-50303',
#  'GRL|Sandwich|sausageMuffin|AAD': 'R-47758',
#  'GRL|Sandwich|Tuna Melt|AAD': 'R-56493',
#  'GRL|Side fries|curly fries|AAD': 'R-71888',
#  'GRL|Side|Chicken Strips|AAD': 'R-44770',
#  'GRL|side|fries|Beer Bat|AAD': 'R-44773',
#  'GRL|Side|hashbrowns|': 'R-61822',
#  'GRL|Side|onion ring|AAD': 'R-71886',
#  'GRL|Side|Potato Fries': 'R-45233',
#  'GRL|Side|Tomato': 'R-44738',
#  'GRL|Side|Yam Fries|AAD': 'R-44774',
#  'GRL|Three Cheese Scramble|AAD': 'R-70696',
#  'GRL|Veggie Chili Dog|AAD': 'R-42127',
#  'GRL|ZooStick|AAD': 'R-69679',
#  'GZA|Bowl|Acorn Squash|AAD': 'R-50363',
#  'GZA|Bowl|BC Tuna ': 'R-50359',
#  'GZA|Bowl|Bibimbap Tofu|AAD': 'R-49761',
#  'GZA|Bowl|chilled crab bowl|AAD': 'R-72103',
#  'GZA|Bowl|Corn togarashi|AAD': 'R-68822',
#  'GZA|Bowl|Crispy Cauli temp|AAD': 'R-64725',
#  'GZA|Bowl|Karaage Chicken|AAD': 'R-50362',
#  'GZA|Bowl|Kitsilano Tofu|AAD': 'R-54342',
#  'GZA|Bowl|Salmon shiso pnzu|AAD': 'R-50360',
#  'GZA|Bowl|SP albacore Tuna|AAD': 'R-65512',
#  'GZA|Bowl|Spicy Beef|AAD': 'R-50361',
#  'GZA|Bowl|Spicy Chicken|AAD': 'R-71000',
#  'GZA|Bowl|spicy ginger broccoli': 'R-70668',
#  'GZA|Bowl|SpicyWaygu|AAD': 'R-73366',
#  'GZA|Bowl|Wakame|AAD': 'R-73615',
#  'GZA|Dashi+Dumps|AAD': 'R-51249',
#  'GZA|ramen broth|Udon': 'R-68982',
#  'GZA|Soup|Miso|AAD': 'R-50508',
#  'HC|Lemon Olive Oil Salmon|AAD': 'R-62715',
#  'HC|Lemon Olive Oil Tofu|AAD': 'R-73542',
#  'HC|Makhani Prawn|AAD': 'R-73594',
#  'HC|Paneer&Tofu TikkaMasala|AAD': 'R-73535',
#  'HC|Tofu Tikka Masala|AAD': 'R-68229',
#  'MED|BOWL|BeefLambGyro|AAD': 'R-73261',
#  'MED|BOWL|FalafelGyro|AAD': 'R-73251',
#  'MED|BOWL|GrandpaJTofu|AAD': 'R-73372',
#  'MED|BOWL|HarissaCauli|AAD': 'R-73254',
#  'MED|BOWL|Lemon Chick Greek|AAD': 'R-73259',
#  'MED|BOWL|PlantbasedPatty|AAD': 'R-73301',
#  'MED|PlantbasedPattyGyro|AAD ': 'R-73300',
#  'MED|PorkPineappleStacker|AAD': 'R-73264',
#  'MED|salad|greek oregano|AAD': 'R-73679',
#  'MED|WayguGyro|AAD': 'R-73205',
#  'NDL|Dan Dan Noodle|TMRW|AAD': 'R-45419',
#  'NDL|Garlic Shio Ramen|AAD': 'R-73425',
#  'NDL|Laksa Eggplant Noodle|AAD': 'R-65671',
#  'NDL|Laksa Tofu Noodle|AAD': 'R-43922',
#  'NDL|Living Tree Ravioli|AAD': 'R-72264',
#  'NDL|Miso Ramen|AAD': 'R-41308',
#  'NDL|PHO Veg Noodle Soup|AAD': 'R-44930',
#  'NDL|Ramen|ADD egg': 'R-73442',
#  'NDL|SOUP|Spinach Gnocchi|AAD': 'R-73656',
#  'NDL|SOUP|Veg Wonton|AAD': 'R-50482',
#  'NDL|Spicy Tan Tan ramen|AAD': 'R-73447',
#  'NDL|Tan Tan Ramen Sesame|AAD': 'R-73302',
#  'NDL|Waygu Ravioli|AAD': 'R-73444',
#  'SAND|Avo BLT ': 'R-54377',
#  'SAND|Beef Dip|AAD': 'R-61012',
#  'SAND|BLT ': 'R-73648',
#  'SAND|chicken Crunch': 'R-61739',
#  'SAND|Chicken Salad': 'R-68083',
#  'SAND|Chickpea Salad': 'R-68078',
#  'SAND|Clubhouse': 'R-61852',
#  'SAND|Egg Salad': 'R-71946',
#  'SAND|Falafel': 'R-68079',
#  'Sand|Pesto Provolone Tom|AAD': 'R-70711',
#  'SAND|Philly Cheesesteak': 'R-50504',
#  'SAND|Portobello|AAD': 'R-71990',
#  'SAND|Prawn po-boy|AAD': 'R-60982',
#  'SAND|Pulled Pork Sandwich|AAD': 'R-68405',
#  'SAND|Roast Beef Full Build': 'R-43885',
#  'SAND|Sand|Meatball Sub|AAD': 'R-47390',
#  'SAND|Sandwich|Bahn Mi': 'R-56491',
#  'SAND|Shrimp remoulade|salad': 'R-56924',
#  'SAND|Tofu Bahn Mi': 'R-68075',
#  'SAND|Turkey Pear & Brie': 'R-61854',
#  'SAND|Vegetable Full Build': 'R-28374',
#  'SANDWICH|Grilled Veg': 'R-61321',
#  'SANDWICH|Ham & Cheese': 'R-68076',
#  'SB|Cereal Hot|Oatmeal': 'R-14201',
#  'SB|congee|RATIO|AAD': 'R-71919',
#  'SIDE BAR|RATIO|AAD ': 'R-71917',
#  'SL|Bacalhau cod |AAD': 'R-72779',
#  'SL|Bacon Pork Loin|AAD|100g': 'R-57257',
#  'SL|Beef Bourguignon|AAD': 'R-72805',
#  'SL|Beef Brisket|AAD|': 'R-49123',
#  'SL|Beef Caldereta|AAD': 'R-71915',
#  'SL|beef coconut stew|AAD': 'R-72339',
#  'SL|Beef flat roast| 125g|AAD': 'R-62209',
#  'SL|Beef Kare-Kare|AAD': 'R-72331',
#  'SL|Beef nilaga|AAD|140g': 'R-71994',
#  'SL|Beef Stew|AAD': 'R-72807',
#  'SL|Big Veg Beet roast|320g|AAD': 'R-65673',
#  'SL|Big Veg Eggplant|320g|AAD': 'R-45101',
#  'SL|Big Veg Zucchini|320g|AAD': 'R-66195',
#  'SL|Big veg|Brussels|Plate|AAD': 'R-62195',
#  'SL|BlueBalsamic|Chkn Thigh|AAD': 'R-71909',
#  'SL|Brazilian Chick Thigh|AAD': 'R-72764',
#  'SL|chicken adobo thigh|AAD': 'R-55304',
#  'SL|Chicken cacciatore|AAD|140g': 'R-57253',
#  'SL|chicken chop suey|AAD|140g': 'R-71993',
#  'SL|chicken manchurian|AAD': 'R-70985',
#  'SL|chicken red thai|AAD|140g': 'R-72340',
#  'SL|Chicken Thigh BBQ|AAD': 'R-72776',
#  'SL|chicken thigh huli-huli|AAD': 'R-72771',
#  'SL|Chicken Tinola|AAD': 'R-72698',
#  'SL|chimichuri thigh|160g|AAD': 'R-57250',
#  'SL|Chix breast tom/basil|AAD': 'R-62227',
#  'SL|Chix Thigh Inasal|AAD': 'R-72717',
#  'SL|Chix Thigh Lemongrass|AAD': 'R-47110',
#  'SL|chkn thigh gulai ayam|AAD': 'R-72714',
#  'SL|chkn thigh TAM|160g|AAD': 'R-72712',
#  'SL|chkn thighCajun|100g|AAD': 'R-72334',
#  'SL|Coconut braisePork|AAD|100g': 'R-71908',
#  'SL|Cod gremolata|85g|AAD': 'R-71916',
#  'SL|CozidoDeFrango ChickStew|SL': 'R-72767',
#  'SL|Ctrs thym chkn breast|AAD': 'R-57256',
#  'SL|Curry chicken wings|Plate': 'R-71911',
#  'SL|Ginger pork loin|125g|AAD': 'R-62159',
#  'SL|Halibut|Feature plate|AAD': 'R-64773',
#  'SL|Herb RST Chicken Thigh|AAD': 'R-72711',
#  "SL|Herb'd Cod|Plate|AAD": 'R-71906',
#  "SL|Herb'd Pork Loin|Plate|AAD": 'R-62215',
#  'SL|Herbed chicken breast|AAD': 'R-44903',
#  'SL|Inihaw Na BaboyPorkChop|AAD': 'R-72724',
#  'SL|Jerk Chicken or Pork|AAD': 'R-72816',
#  'SL|Lamb Roast Plate|AAD': 'R-51176',
#  'SL|Lemon herb Cod|Plate|AAD': 'R-71912',
#  'SL|Lemon tym Chicken Thigh|AAD': 'R-62207',
#  'SL|Olive dressed Chicken|AAD': 'R-58436',
#  'SL|Panang Curry|AAD': 'R-71995',
#  'SL|Peri-Peri Chicken Thigh|AAD': 'R-71913',
#  'SL|Pork Babi Chin|AAD': 'R-72716',
#  "SL|Pork Chop Herb'd|Plate|AAD": 'R-62297',
#  'SL|Pork Chop huli-huli|AAD': 'R-72336',
#  'SL|pork chop|green peppercorn': 'R-62220',
#  'SL|Pork Chop|Mole|AAD': 'R-71914',
#  'SL|Pork Coconut Stew|AAD': 'R-72803',
#  'SL|Pork Feijoada|AAD': 'R-72791',
#  'SL|Pork poblano |AAD': 'R-72713',
#  'SL|Pork|TikaMasala|AAD': 'R-42358',
#  'SL|Rendang Beef|AAD': 'R-72737',
#  'SL|Rosemary Chicken|AAD': 'R-62233',
#  'SL|Salmon Cajun|100g|AAD': 'R-62238',
#  'SL|Salmon ginger|AAD': 'R-62072',
#  'SL|Salmon spicy basil|100g|AAD': 'R-62235',
#  'SL|Satay Pork Chop|AAD': 'R-72735',
#  'SL|Sauce|RATIO|NEW': 'R-62302',
#  'SL|Shepherd Pie|AAD': 'R-49182',
#  'SL|side Vegetable| Ratio': 'R-57246',
#  'SL|Side|beans and pesto': 'R-57243',
#  'SL|Side|Beans Romano ': 'R-37868',
#  'SL|Side|Potato baked': 'R-44814',
#  'SL|Side|Potato Rosemary Roast': 'R-36874',
#  'SL|Side|Potato Smash Olive Oil': 'R-47746',
#  'SL|Side|Quinoa': 'R-46330',
#  'SL|Side|Rice Brown': 'R-36854',
#  'SL|Side|Roasted Potato': 'R-52652',
#  'SL|Side|SorghumRoasted': 'R-36853',
#  'SL|SIDEs x1|RATIO': 'R-62303',
#  'SL|SideYam Roasted Sage': 'R-44810',
#  'SL|Singigang Na Baboy|AAD': 'R-72693',
#  'SL|Sinigang Pork||AAD': 'R-71992',
#  'SL|Squash bowl|AAD': 'R-62216',
#  'SL|Starches blend|Beans legume': 'R-57242',
#  'SL|Starches Blend|Potatoes': 'R-57240',
#  'SL|Starches blend|Rice & grain': 'R-57241',
#  'SL|Starches|RATIO|NEW': 'R-57244',
#  'SL|Turkey dinner|140g|AAD': 'R-62105',
#  'SL|Veg blend|SL': 'R-57248',
#  'SL|Veg blend|UBC': 'R-57247',
#  'SL|Vegetable lasagne|220g|aad': 'R-62144',
#  'SL|vegetables x2|RATIO|NEW': 'R-62193',
#  'SL|Yam Stuffed Chicken|AAD': 'R-62240',
#  'FF|Pasta|Primavera|AAD': 'R-49596',
#  'FLX|Benny|Classic|AAD': 'R-62001',
#  'GRL|Benny classic|X1': 'R-62409',
#  'GRL|Burger|Planetary|Greek|AAD': 'R-71962',
#  'GRL|GrilledCheese|tom&goat|AAD': 'R-62514',
#  'GRL|Salad|Gather Greenery|SIDE': 'R-65756',
#  'SL|BBQ Chicken Thigh|AAD': 'R-73169',
#  'SL|BBQ Porkchop|AAD': 'R-72778',
#  'SL|Lemon Pepper Chichen|AAD': 'R-72819',
#  'DEL|Strawberry Salad|AAD*': 'R-70824',
#  'FF|Pasta|Avocado Spin old': 'R-46347',
#  'FF|Toast|ChiliCrunCAvocado|AAD': 'R-73668',
#  'COOKED|Veg|Ginger Garlic Broc': 'P-44753',
#  'HS|Pasta Bar Protien|BV Test': 'P-55167',
#  'MIX|Pasta Bar Vegetables': 'P-46824',
#  'PREP|Dip|Tzatziki|MED*': 'P-73341',
#  'PREP|Lemongrass Pork Chop|SL': 'P-72728',
#  'SAUCE|Chipotle Mayo|GRL': 'P-32244',
#  'PREP|SALAD|Tomato CucMint|MED': 'P-73472',
#  'SALAD|QuinoaTabbouleh|MED*': 'P-73266',
#  'FRIES 3/8IN*CRINKLE': 'I-71938'}

# %%
final2 = final.copy()
final2 = add_menu_names(final, OK_list)
final2.to_csv(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.csv",
                  index=False)
final2.to_csv(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.xlsx",
                  index=False)

# %%
# # # ADDED FOR GATHER:
# final2 = pd.read_csv("C:/Users/ENTER_HERE/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.csv")
# final2.head()

# %%
counts = create_final_counts(final2)
all_ghg_num = counts["GHG Label Counts"].sum()
all_num = counts["Combined Label Counts"].sum()
sum_row = pd.Series(data={"GHG Label Counts": all_ghg_num, "Combined Label Counts": all_num}, name="Sum")
sum_row
# Out:
# 133 124 154
# GHG Label Counts         411
# Combined Label Counts    411
# Name: Sum, dtype: int64

# %%
# counts = counts.append(sum_row, ignore_index=False)
counts.to_csv(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/"+restaurant_name+"_Summary.csv", index=False)
counts_print = pd.concat([counts, sum_row], ignore_index=True)
counts
# Out:
#         GHG Label Counts  Combined Label Counts
# Red                  124                    133
# Yellow               135                    124
# Green                152                    154

# %%
# THE BLUE BAR REPRESENTS THE SUM ROW WHICH IS THE TOTAL NUMBER OF RECIPES THAT HAVE BEEN ASSIGNED A LABEL
# EACH BAR REPRESENTS THE # OF RECIPES THAT WERE LABELLED WITH THAT SPECIFIC COLOUR

fig = create_visualizations(counts)
fig
# Out:
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_88234/3450104400.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(data=df, x=df["Color"], y=df["GHG Label Counts"], ax=axes[0], palette=palette)
# /var/folders/bq/zkgc6_d969x_x5nsl5fy0vkh0000gn/T/ipykernel_88234/3450104400.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.barplot(data=df, x=df["Color"], y=df["Combined Label Counts"], ax=axes[1], palette=palette)

# %%
final2.head()
# Out:
#   Category Displayed Name   ProdId                    Description  \
# 0      DEL       smoothie  R-73669  DEL|smoothie| mango pineapple
# 1      DEL       Smoothie  R-56613   DEL|Smoothie|Almonds forever
# 2      DEL       Smoothie  R-44306    DEL|Smoothie|Banana Matcha
# 3      DEL       Smoothie  R-43697  DEL|Smoothie|Blueberry Boost
# 4      DEL       Smoothie  R-46074    DEL|Smoothie|Bna Almnd Buta
#
#     SalesGroup  Weight (g)  GHG Emission (g)  N lost (g)  Land Use (m^2)  \
# 0  GV - DELISH       350.0         77.151358    0.375085        0.148062
# 1  GV - DELISH        71.0        324.658690    1.122366        0.675339
# 2  GV - DELISH         1.0          0.780648    0.004219        0.001520
# 3  GV - DELISH         1.0          4.520079    0.018895        0.003462
# 4  GV - DELISH       365.0        169.432593    0.488466        0.549266
#
#    Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                        0.59                           1.92
# 1                      101.87                        7213.85
# 2                        0.20                          11.70
# 3                        0.77                          32.31
# 4                        2.19                         128.61
#
#    GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                    22.04               0.11
# 1                   457.27               1.58
# 2                    78.06               0.42
# 3                   452.01               1.89
# 4                    46.42               0.13
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               0.17                                  0.55
# 1                             143.48                              10160.35
# 2                              20.00                               1170.00
# 3                              77.00                               3231.00
# 4                               0.60                                 35.24
#
#    Land Use (m^2) / 100g GHG Only Label Combined Label
# 0                   0.04          Green          Green
# 1                   0.95            Red            Red
# 2                   0.15          Green          Green
# 3                   0.35            Red            Red
# 4                   0.15          Green          Green

# %%
final3 = final2.drop(columns=['Category', 'Displayed Name', 'Weight (g)', 'GHG Only Label'])

# %%
final3.head()
# Out:
#     ProdId                    Description   SalesGroup  GHG Emission (g)  \
# 0  R-73669  DEL|smoothie| mango pineapple  GV - DELISH         77.151358
# 1  R-56613   DEL|Smoothie|Almonds forever  GV - DELISH        324.658690
# 2  R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH          0.780648
# 3  R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH          4.520079
# 4  R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH        169.432593
#
#    N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0    0.375085        0.148062                        0.59
# 1    1.122366        0.675339                      101.87
# 2    0.004219        0.001520                        0.20
# 3    0.018895        0.003462                        0.77
# 4    0.488466        0.549266                        2.19
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                           1.92                    22.04               0.11
# 1                        7213.85                   457.27               1.58
# 2                          11.70                    78.06               0.42
# 3                          32.31                   452.01               1.89
# 4                         128.61                    46.42               0.13
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               0.17                                  0.55
# 1                             143.48                              10160.35
# 2                              20.00                               1170.00
# 3                              77.00                               3231.00
# 4                               0.60                                 35.24
#
#    Land Use (m^2) / 100g Combined Label
# 0                   0.04          Green
# 1                   0.95            Red
# 2                   0.15          Green
# 3                   0.35            Red
# 4                   0.15          Green

# %%
final3.rename(columns={'ProdId': 'Optimum Control ID', 'Description': 'OC Description'}, inplace=True)

# %%
final3.head()
# Out:
#   Optimum Control ID                 OC Description   SalesGroup  \
# 0            R-73669  DEL|smoothie| mango pineapple  GV - DELISH
# 1            R-56613   DEL|Smoothie|Almonds forever  GV - DELISH
# 2            R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH
# 3            R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH
# 4            R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH
#
#    GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0         77.151358    0.375085        0.148062                        0.59
# 1        324.658690    1.122366        0.675339                      101.87
# 2          0.780648    0.004219        0.001520                        0.20
# 3          4.520079    0.018895        0.003462                        0.77
# 4        169.432593    0.488466        0.549266                        2.19
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                           1.92                    22.04               0.11
# 1                        7213.85                   457.27               1.58
# 2                          11.70                    78.06               0.42
# 3                          32.31                   452.01               1.89
# 4                         128.61                    46.42               0.13
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               0.17                                  0.55
# 1                             143.48                              10160.35
# 2                              20.00                               1170.00
# 3                              77.00                               3231.00
# 4                               0.60                                 35.24
#
#    Land Use (m^2) / 100g Combined Label
# 0                   0.04          Green
# 1                   0.95            Red
# 2                   0.15          Green
# 3                   0.35            Red
# 4                   0.15          Green

# %%
final3['Red'] = final3['Combined Label'] == 'Red'
final3['Yellow'] = final3['Combined Label'] == 'Yellow'
final3['Green'] = final3['Combined Label'] == 'Green'

# %%
final3.head()
# Out:
#   Optimum Control ID                 OC Description   SalesGroup  \
# 0            R-73669  DEL|smoothie| mango pineapple  GV - DELISH
# 1            R-56613   DEL|Smoothie|Almonds forever  GV - DELISH
# 2            R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH
# 3            R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH
# 4            R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH
#
#    GHG Emission (g)  N lost (g)  Land Use (m^2)  Freshwater Withdrawals (L)  \
# 0         77.151358    0.375085        0.148062                        0.59
# 1        324.658690    1.122366        0.675339                      101.87
# 2          0.780648    0.004219        0.001520                        0.20
# 3          4.520079    0.018895        0.003462                        0.77
# 4        169.432593    0.488466        0.549266                        2.19
#
#    Stress-Weighted Water Use (L)  GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                           1.92                    22.04               0.11
# 1                        7213.85                   457.27               1.58
# 2                          11.70                    78.06               0.42
# 3                          32.31                   452.01               1.89
# 4                         128.61                    46.42               0.13
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               0.17                                  0.55
# 1                             143.48                              10160.35
# 2                              20.00                               1170.00
# 3                              77.00                               3231.00
# 4                               0.60                                 35.24
#
#    Land Use (m^2) / 100g Combined Label    Red  Yellow  Green
# 0                   0.04          Green  False   False   True
# 1                   0.95            Red   True   False  False
# 2                   0.15          Green  False   False   True
# 3                   0.35            Red   True   False  False
# 4                   0.15          Green  False   False   True

# %%
import pandas as pd


desired_column_order = [
    'Optimum Control ID', 'OC Description', 'SalesGroup', 'Combined Label', 'Red', 'Yellow', 'Green',
    'GHG Emission (g)', 'N lost (g)', 'Land Use (m^2)', 'Freshwater Withdrawals (L)', 
    'Stress-Weighted Water Use (L)', 'GHG Emission (g) / 100g', 'N lost (g) / 100g', 
    'Freshwater Withdrawals (L) / 100g', 'Stress-Weighted Water Use (L) / 100g', 
    'Land Use (m^2) / 100g'
]

# Create a new DataFrame with the desired column order
data_reordered = final3[desired_column_order]

# Print the reordered DataFrame
data_reordered.head()
# Out:
#   Optimum Control ID                 OC Description   SalesGroup  \
# 0            R-73669  DEL|smoothie| mango pineapple  GV - DELISH
# 1            R-56613   DEL|Smoothie|Almonds forever  GV - DELISH
# 2            R-44306    DEL|Smoothie|Banana Matcha   GV - DELISH
# 3            R-43697  DEL|Smoothie|Blueberry Boost   GV - DELISH
# 4            R-46074    DEL|Smoothie|Bna Almnd Buta  GV - DELISH
#
#   Combined Label    Red  Yellow  Green  GHG Emission (g)  N lost (g)  \
# 0          Green  False   False   True         77.151358    0.375085
# 1            Red   True   False  False        324.658690    1.122366
# 2          Green  False   False   True          0.780648    0.004219
# 3            Red   True   False  False          4.520079    0.018895
# 4          Green  False   False   True        169.432593    0.488466
#
#    Land Use (m^2)  Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0        0.148062                        0.59                           1.92
# 1        0.675339                      101.87                        7213.85
# 2        0.001520                        0.20                          11.70
# 3        0.003462                        0.77                          32.31
# 4        0.549266                        2.19                         128.61
#
#    GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                    22.04               0.11
# 1                   457.27               1.58
# 2                    78.06               0.42
# 3                   452.01               1.89
# 4                    46.42               0.13
#
#    Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                               0.17                                  0.55
# 1                             143.48                              10160.35
# 2                              20.00                               1170.00
# 3                              77.00                               3231.00
# 4                               0.60                                 35.24
#
#    Land Use (m^2) / 100g
# 0                   0.04
# 1                   0.95
# 2                   0.15
# 3                   0.35
# 4                   0.15

# %%
data_reordered.to_csv(os.getcwd() + "/data/final/2023_2024_CFFS_Outcomes/Labelled_Data_"+restaurant_name+"_for_nutrislice.csv",
                  index=False)
