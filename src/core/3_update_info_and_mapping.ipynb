# %% [markdown]
# # Climate-Friendly Food Systems (CFFS) Labelling Project
#
# ### The University of British Columbia
#
# ***
#
# ## Part III: Update Information and Mapping

# %% [markdown]
# ## Set up and Import Libraries

# %%
#pip install -r requirements.txt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import csv
from itertools import islice
from decimal import Decimal
import xml.etree.ElementTree as et
from xml.etree.ElementTree import parse
import openpyxl
import pytest
from datetime import datetime

# %%
# RUN ONLY ONCE
# os.chdir is used to change the current directory to the specified path
os.chdir("../") # Sets path to the repo folder as it is one level above where this file exists!
path = os.getcwd()
print(path)
# Out:
# /Users/vivaanwadhwa/Documents/GitHub/CFFS_sharon_2024

# %% [markdown]
# ***
# ## Import Preprocessed Datasets

# %%
# Creates a DataFrame from reading a csv file 
Preps = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaning", "Preps_Unit_Cleaned.csv"))
Preps.head()
# Out:
#     PrepId                  Description  PakQty PakUOM       InventoryGroup  \
# 0  P-68207  24|BATCH|Poblano Pork Stew*   100.0    PTN                 PREP
# 1  P-61322                  AIOLI|Pesto     4.0      L  ZDONT USE OK - PREP
# 2  P-46066           Almond Milk Yeild    900.0     ml                  NaN
# 3   P-8814    Aoli- RoastedGarlic Thyme     1.1      L                  NaN
# 4  P-49605                 APPLE|Cubed     75.0      g                  NaN
#
#    StdQty StdUom
# 0   100.0    PTN
# 1  4000.0     ml
# 2   900.0     ml
# 3  1100.0     ml
# 4    75.0      g

# %%
# Creates a DataFrame from reading a csv file 
ghge_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "ghge_factors.csv"))
ghge_factors.head()
# Out:
#    Category ID              Food Category  \
# 0            1        beef & buffalo meat
# 1            2    lamb/mutton & goat meat
# 2            3            pork (pig meat)
# 3            4  poultry (chicken, turkey)
# 4            5                     butter
#
#    Active Total Supply Chain Emissions (kg CO2 / kg food)
# 0                                            41.3463
# 1                                            41.6211
# 2                                             9.8315
# 3                                             4.3996
# 4                                            11.4316

# %%
# Creates a DataFrame from reading a csv file 
nitro_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "nitrogen_factors.csv"))
nitro_factors.head()
# Out:
#    Category ID              Food Category  g N lost/kg product
# 0            1        beef & buffalo meat               329.50
# 1            2    lamb/mutton & goat meat               231.15
# 2            3            pork (pig meat)               132.80
# 3            4  poultry (chicken, turkey)               116.80
# 4            5                     butter               100.35

# %%
# Creates a DataFrame from reading a csv file 
water_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "water_factors.csv"))
water_factors.head()
# Out:
#    Category ID              Food Category  Freshwater Withdrawals (L/FU)  \
# 0            1        beef & buffalo meat                       1677.200
# 1            2    lamb/mutton & goat meat                        461.200
# 2            3            pork (pig meat)                       1810.300
# 3            4  poultry (chicken, turkey)                        370.300
# 4            5                     butter                       1010.176
#
#    Stress-Weighted Water Use (L/FU)
# 0                         61309.000
# 1                           258.900
# 2                         54242.700
# 3                           333.500
# 4                         50055.168

# %%
# Creates a DataFrame from reading a csv file 
land_factors = pd.read_csv(os.path.join(os.getcwd(), "data", "external", "land_factors.csv"))
land_factors.rename(columns={'km^2 land use/kg product': 'Land Use (m^2)'}, inplace=True)
land_factors['Land Use (m^2)'] *= 1000
land_factors.head()
# Out:
#    Category ID              Food Category  Land Use (m^2)
# 0            1        beef & buffalo meat         0.12645
# 1            2    lamb/mutton & goat meat         0.14320
# 2            3            pork (pig meat)         0.02102
# 3            4  poultry (chicken, turkey)         0.01151
# 4            5                     butter         0.01395

# %%
# Load current Items List with assigned Emission Factors Category ID
Items_Assigned = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "Items_List_Assigned.csv"))
Items_Assigned.head()
# Out:
#     ItemId  CategoryID               Description  CaseQty CaseUOM  PakQty  \
# 0  I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1  I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2   I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3  I-37005         1.0            BEEF MEATBALLS     4.54      Kg  1000.0
# 4  I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
#
#   PakUOM InventoryGroup Food Category
# 0     Kg           MEAT           NaN
# 1     Kg           MEAT           NaN
# 2     Kg           MEAT           NaN
# 3      g           MEAT           NaN
# 4      g           MEAT           NaN

# %%
new_items = pd.read_csv("data/mapping/new items added/New_Items_2024/New_Items_Added_2024-08-30.csv")
new_items
# Out:
#       ItemId  CategoryID                     Description  CaseQty CaseUOM  \
# 0     I-1497          31                DATES MACERATED      12.5      Kg
# 1    I-63072          30             DRINK SOY ORG 946ML     12.0   tetra
# 2     I-3299          26           GRANOLA HONEY ALMOND       5.0      Kg
# 3    I-67010          26               GRANOLA MAPLE NUT      3.0      Kg
# 4    I-11341          24      MUFFIN BATT DBL CHOCO CHIP     16.0      lb
# 5    I-57771          24        MUFFIN BATT FRUIT MEDLEY      1.0    pail
# 6    I-11345          24       MUFFIN BATTER CARROT SCAP     16.0      lb
# 7    I-62801          24    MUFFIN CHOCOLATE CRAN  VEGAN      1.0      CT
# 8    I-29519          49  OLIVE NICOISE PITTED MASS DI P      2.4      Kg
# 9    I-57772          24               OREO MEDIUM GRIND      1.0      cs
# 10   I-71841          24    PASTA PENNE*RIGAT HEAVY WALL      2.0     bag
# 11   I-19567          19       PEANUT BUTTER NATURAL TFC      1.0      PL
# 12   I-23341          31                  PEARS BARTLETT      5.0      lb
# 13    I-4821          40           PUMPKIN (FULL-SIZE)BC      1.0      lb
# 14    I-3469          40              PUMPKIN PUREE*CAN       6.0     can
# 15    I-5112          12     SAL REG MINCED WILD O/WISE       1.0      lb
# 16    I-4906          34         STRAWBERRIES DRISCOLLUS      1.0      lb
# 17    I-1507          24               WHEAT GERM ROGERS     15.0      Kg
# 18   I-1033p          61               WRAP FOIL 12X1000      1.0      CT
# 19   I-1119p          61               WRAP FOIL 18X1000      1.0      CT
# 20   I-1126p          61               WRAP FOIL 24X1000      1.0      CT
# 21    I-1484          53                FLAVOURS COFFEE       4.0       L
# 22   I-72206          20            TOFU JUST SMOKE BULK      8.0     pak
# 23  I-102947          20               WAGYU UMAMI*STRIP      1.0      lb
#
#      PakQty PakUOM           InventoryGroup
# 0      1.00     Kg   BAKING-RAW INGREDIENTS
# 1    946.00     ml                    DAIRY
# 2      1.00     Kg           FOOD - GROCERY
# 3      1.00     Kg           FOOD - GROCERY
# 4      1.00     lb   BAKING-RAW INGREDIENTS
# 5     16.00     lb   BAKING-RAW INGREDIENTS
# 6      1.00     lb   BAKING-RAW INGREDIENTS
# 7      1.00     CT              BAKED GOODS
# 8      1.00     Kg           FOOD - GROCERY
# 9     11.30     Kg              BAKED GOODS
# 10     4.54     Kg           FOOD - GROCERY
# 11    10.00     Kg           FOOD - GROCERY
# 12     1.00     lb                  PRODUCE
# 13     1.00     lb                  PRODUCE
# 14  2840.00     ml           FOOD - GROCERY
# 15     1.00     lb                  SEAFOOD
# 16     1.00     lb                  PRODUCE
# 17     1.00     Kg   BAKING-RAW INGREDIENTS
# 18     1.00     CT  BAKING-RAW INGREDIENTS
# 19     1.00     CT   BAKING-RAW INGREDIENTS
# 20     1.00     CT   BAKING-RAW INGREDIENTS
# 21     2.41     Kg   BAKING-RAW INGREDIENTS
# 22   225.00      g           FOOD - GROCERY
# 23     1.00     lb                     MEAT

# %%
item_nonstd = pd.read_csv("data/cleaning/Items_Nonstd.csv")
item_nonstd
# Out:
# Empty DataFrame
# Columns: [IngredientId, Qty, Uom, Conversion, InvFactor, Recipe]
# Index: []

# %%
preps_nonstd = pd.read_csv("data/cleaning/Preps_NonstdUom.csv")
preps_nonstd
# Out:
# Empty DataFrame
# Columns: [PrepId, Description, PakQty, PakUOM, InventoryGroup, StdQty, StdUom]
# Index: []

# %%
conv_updatecov = pd.read_csv("data/cleaning/update/Conv_UpdateConv.csv")
conv_updatecov
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0        I-67659    0.008818             1.0           each       113.398
# 1        I-28697    0.005181             1.0             ea       193.000
# 2        I-47441    0.005181             1.0             ea       193.000
# 3         I-1905    0.012500             1.0             CT        80.000
# 4        I-47440    0.005051             1.0             ea       198.000
# ..           ...         ...             ...            ...           ...
# 627      I-1119p    1.000000             1.0             CT         0.000
# 628      I-1004p    1.000000             1.0             CT         0.000
# 629      I-1126p    1.000000             1.0             CT         0.000
# 630      I-25121    1.000000             1.0             ea         0.000
# 631      I-62801    0.012000             6.0             CT       500.000
#
#     ConvertToUom
# 0              g
# 1              g
# 2              g
# 3              g
# 4              g
# ..           ...
# 627            g
# 628            g
# 629            g
# 630            g
# 631            g
#
# [632 rows x 6 columns]

# %%
conv_updatecov.loc[conv_updatecov["ConversionId"] == "P-54581"]
# Out:
# Empty DataFrame
# Columns: [ConversionId, Multiplier, ConvertFromQty, ConvertFromUom, ConvertToQty, ConvertToUom]
# Index: []

# %%
Preps.loc[Preps["PrepId"] == "P-54581"]
# Out:
# Empty DataFrame
# Columns: [PrepId, Description, PakQty, PakUOM, InventoryGroup, StdQty, StdUom]
# Index: []

# %% [markdown]
# # Update Conversion_Added.csv

# %%
conversions_added = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaning", "Conversions_Added.csv"))
conversions_added
# Out:
#     ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0            NaN    1.000000             1.0            XXX          1.00
# 1            NaN    0.877193             1.0          1.14L          1.14
# 2            NaN    0.666667             1.0           1.5L          1.50
# 3            NaN    0.571429             1.0         1.75 L          1.75
# 4            NaN    0.500000             1.0             2L          2.00
# ..           ...         ...             ...            ...           ...
# 713      I-1119p    1.000000             1.0             CT          0.00
# 714      I-1004p    1.000000             1.0             CT          0.00
# 715      I-1126p    1.000000             1.0             CT          0.00
# 716      I-25121    1.000000             1.0             ea          0.00
# 717      I-62801    0.012000             6.0             CT        500.00
#
#     ConvertToUom
# 0              L
# 1              L
# 2              L
# 3              L
# 4              L
# ..           ...
# 713            g
# 714            g
# 715            g
# 716            g
# 717            g
#
# [718 rows x 6 columns]

# %%
# Concatenate the DataFrames
combined_df = pd.concat([conv_updatecov, conversions_added], ignore_index=True)
combined_df
# Out:
#      ConversionId  Multiplier  ConvertFromQty ConvertFromUom  ConvertToQty  \
# 0         I-67659    0.008818             1.0           each       113.398
# 1         I-28697    0.005181             1.0             ea       193.000
# 2         I-47441    0.005181             1.0             ea       193.000
# 3          I-1905    0.012500             1.0             CT        80.000
# 4         I-47440    0.005051             1.0             ea       198.000
# ...           ...         ...             ...            ...           ...
# 1345      I-1119p    1.000000             1.0             CT         0.000
# 1346      I-1004p    1.000000             1.0             CT         0.000
# 1347      I-1126p    1.000000             1.0             CT         0.000
# 1348      I-25121    1.000000             1.0             ea         0.000
# 1349      I-62801    0.012000             6.0             CT       500.000
#
#      ConvertToUom
# 0               g
# 1               g
# 2               g
# 3               g
# 4               g
# ...           ...
# 1345            g
# 1346            g
# 1347            g
# 1348            g
# 1349            g
#
# [1350 rows x 6 columns]

# %%
# Add the conv_updatecov file to the masterfile, Conversions_Added
path = os.path.join(os.getcwd(), "data", "cleaning", "Conversions_Added.csv")
combined_df.to_csv(path, index = False, header = True)

# %% [markdown]
# ***
# ## Import Update Info

# %%
# Import list of prep that need convert uom to standard uom manually
Manual_PrepU = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaning", "update", "Preps_UpdateUom.csv"))
# Here we can see that UOM examples are: each, ea, slice
Manual_PrepU.head()
# Out:
#     PrepId                 Description  PakQty PakUOM InventoryGroup   StdQty  \
# 0  P-54697             LEMON|Wedge 1/8     8.0   each           PREP     84.0
# 1  P-35132  MARINATED|Lemon & Herb Chx   185.0     ea           PREP  24050.0
# 2  P-51992   YIELD|Bread|Sourdough 5/8    36.0  slice            NaN   1620.0
# 3  P-26234  BATCH|Roasted Garlic Bread    16.0     ea           PREP   1280.0
# 4  P-26170           GRILLED|NaanBread     1.0     ea           PREP    125.0
#
#   StdUom
# 0      g
# 1      g
# 2      g
# 3      g
# 4      g

# %%
# The row of the DatFrame that contains the PrepId == P-54581
Manual_PrepU.loc[Manual_PrepU["PrepId"] == "P-54581"]
# Out:
#       PrepId             Description  PakQty PakUOM InventoryGroup  StdQty  \
# 212  P-54581  SLICE|Multigrain Bread    22.0  slice            NaN    38.0
#
#     StdUom
# 212      g

# %%
# Select the file path for new items list with category id
New_Items_Added = pd.read_csv("data/mapping/new items added/New_Items_2024/New_Items_Added_2024-08-30.csv")
New_Items_Added.tail(15)
# Out:
#       ItemId  CategoryID                   Description  CaseQty CaseUOM  \
# 9    I-57772          24             OREO MEDIUM GRIND      1.0      cs
# 10   I-71841          24  PASTA PENNE*RIGAT HEAVY WALL      2.0     bag
# 11   I-19567          19     PEANUT BUTTER NATURAL TFC      1.0      PL
# 12   I-23341          31                PEARS BARTLETT      5.0      lb
# 13    I-4821          40         PUMPKIN (FULL-SIZE)BC      1.0      lb
# 14    I-3469          40            PUMPKIN PUREE*CAN       6.0     can
# 15    I-5112          12   SAL REG MINCED WILD O/WISE       1.0      lb
# 16    I-4906          34       STRAWBERRIES DRISCOLLUS      1.0      lb
# 17    I-1507          24             WHEAT GERM ROGERS     15.0      Kg
# 18   I-1033p          61             WRAP FOIL 12X1000      1.0      CT
# 19   I-1119p          61             WRAP FOIL 18X1000      1.0      CT
# 20   I-1126p          61             WRAP FOIL 24X1000      1.0      CT
# 21    I-1484          53              FLAVOURS COFFEE       4.0       L
# 22   I-72206          20          TOFU JUST SMOKE BULK      8.0     pak
# 23  I-102947          20             WAGYU UMAMI*STRIP      1.0      lb
#
#      PakQty PakUOM           InventoryGroup
# 9     11.30     Kg              BAKED GOODS
# 10     4.54     Kg           FOOD - GROCERY
# 11    10.00     Kg           FOOD - GROCERY
# 12     1.00     lb                  PRODUCE
# 13     1.00     lb                  PRODUCE
# 14  2840.00     ml           FOOD - GROCERY
# 15     1.00     lb                  SEAFOOD
# 16     1.00     lb                  PRODUCE
# 17     1.00     Kg   BAKING-RAW INGREDIENTS
# 18     1.00     CT  BAKING-RAW INGREDIENTS
# 19     1.00     CT   BAKING-RAW INGREDIENTS
# 20     1.00     CT   BAKING-RAW INGREDIENTS
# 21     2.41     Kg   BAKING-RAW INGREDIENTS
# 22   225.00      g           FOOD - GROCERY
# 23     1.00     lb                     MEAT

# %%
# Import list of items that adjusted GHGe factor manually
Manual_Factor = pd.read_csv(os.path.join(os.getcwd(), "data", "mapping", "Manual_Adjust_Factors.csv"))
Manual_Factor['Land Use (m^2)'] = 0
Manual_Factor.head()
# Out:
#     ItemId  CategoryID                   Description  CaseQty CaseUOM  PakQty  \
# 0  I-52090        59.0  BURGER BEEF & MUSHROOM HALAL      1.0      cs   48.00
# 1  I-45558        59.0           Prep-Vegan Parmesan   1000.0       g    1.00
# 2   I-3352        59.0        MAYONNAISE PAIL TFC 4L      2.0    each    4.00
# 3   I-3223        59.0  COCONUT MILK 17/19% MILK FAT      6.0  LG CAN    2.84
# 4   I-2898        59.0      MUSTARD DIJON WINE FLEUR      6.0     jar    1.00
#
#   PakUOM   InventoryGroup  \
# 0     CT             MEAT
# 1      g  PRODUCTION FOOD
# 2      L   FOOD - GROCERY
# 3      L   FOOD - GROCERY
# 4     Kg   FOOD - GROCERY
#
#    Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                           25.00894
# 1                                            3.85686
# 2                                            3.55000
# 3                                            3.50000
# 4                                            3.32600
#
#    g N lost/kg product  Freshwater Withdrawals (L/FU)  \
# 0               200.86                        1038.84
# 1                 0.00                           0.00
# 2                 0.00                           0.00
# 3                 0.00                           1.00
# 4                 0.00                           0.00
#
#    Stress-Weighted Water Use (L/FU)  Land Use (m^2)
# 0                           37961.2               0
# 1                               0.0               0
# 2                               0.0               0
# 3                               1.0               0
# 4                               0.0               0

# %% [markdown]
# ### Update Correct Uom for Preps

# %%
# Update prep list with manually adjusted uom
for index, row in Manual_PrepU.iterrows():
    PrepId = Manual_PrepU.loc[index, 'PrepId']
    qty = Manual_PrepU.loc[index, 'StdQty']
    uom = Manual_PrepU.loc[index, 'StdUom']
    Preps.loc[Preps['PrepId'] == PrepId, 'StdQty'] = qty
    Preps.loc[Preps['PrepId'] == PrepId, 'StdUom'] = uom

# %%
Preps.drop_duplicates(subset=['PrepId'], inplace=True,)

# %%
Preps.head()
# Out:
#     PrepId                  Description  PakQty PakUOM       InventoryGroup  \
# 0  P-68207  24|BATCH|Poblano Pork Stew*   100.0    PTN                 PREP
# 1  P-61322                  AIOLI|Pesto     4.0      L  ZDONT USE OK - PREP
# 2  P-46066           Almond Milk Yeild    900.0     ml                  NaN
# 3   P-8814    Aoli- RoastedGarlic Thyme     1.1      L                  NaN
# 4  P-49605                 APPLE|Cubed     75.0      g                  NaN
#
#     StdQty StdUom
# 0  28800.0      g
# 1   4000.0     ml
# 2    900.0     ml
# 3   1100.0     ml
# 4     75.0      g

# %%
Preps.shape
# Out:
# (903, 7)

# %%
path = os.path.join(os.getcwd(), "data", "cleaning", "Preps_List_Cleaned.csv")
Preps.to_csv(path, index = False, header = True)

# %%
Items_Assigned.head()
# Out:
#     ItemId  CategoryID               Description  CaseQty CaseUOM  PakQty  \
# 0  I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1  I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2   I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3  I-37005         1.0            BEEF MEATBALLS     4.54      Kg  1000.0
# 4  I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
#
#   PakUOM InventoryGroup Food Category
# 0     Kg           MEAT           NaN
# 1     Kg           MEAT           NaN
# 2     Kg           MEAT           NaN
# 3      g           MEAT           NaN
# 4      g           MEAT           NaN

# %%
New_Items_Added.head()
# Out:
#     ItemId  CategoryID                 Description  CaseQty CaseUOM  PakQty  \
# 0   I-1497          31            DATES MACERATED      12.5      Kg     1.0
# 1  I-63072          30         DRINK SOY ORG 946ML     12.0   tetra   946.0
# 2   I-3299          26       GRANOLA HONEY ALMOND       5.0      Kg     1.0
# 3  I-67010          26           GRANOLA MAPLE NUT      3.0      Kg     1.0
# 4  I-11341          24  MUFFIN BATT DBL CHOCO CHIP     16.0      lb     1.0
#
#   PakUOM          InventoryGroup
# 0     Kg  BAKING-RAW INGREDIENTS
# 1     ml                   DAIRY
# 2     Kg          FOOD - GROCERY
# 3     Kg          FOOD - GROCERY
# 4     lb  BAKING-RAW INGREDIENTS

# %% [markdown]
# ### Import List of New Items with Emission Factors Category ID Assigned

# %%
frames = [Items_Assigned, New_Items_Added]
Items_Assigned_Updated = pd.concat(frames).reset_index(drop=True, inplace=False).drop_duplicates()
Items_Assigned_Updated.head()
# Out:
#     ItemId  CategoryID               Description  CaseQty CaseUOM  PakQty  \
# 0  I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg     1.0
# 1  I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg     1.0
# 2   I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg     1.0
# 3  I-37005         1.0            BEEF MEATBALLS     4.54      Kg  1000.0
# 4  I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg  1000.0
#
#   PakUOM InventoryGroup Food Category
# 0     Kg           MEAT           NaN
# 1     Kg           MEAT           NaN
# 2     Kg           MEAT           NaN
# 3      g           MEAT           NaN
# 4      g           MEAT           NaN

# %%
Items_Assigned_Updated
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup Food Category
# 0        1.00     Kg                    MEAT           NaN
# 1        1.00     Kg                    MEAT           NaN
# 2        1.00     Kg                    MEAT           NaN
# 3     1000.00      g                    MEAT           NaN
# 4     1000.00      g                    MEAT           NaN
# ...       ...    ...                     ...           ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS           NaN
# 2987     1.00     CT  BAKING-RAW INGREDIENTS           NaN
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS           NaN
# 2989   225.00      g          FOOD - GROCERY           NaN
# 2990     1.00     lb                    MEAT           NaN
#
# [2991 rows x 9 columns]

# %%
Items_Assigned_Updated.shape
# Out:
# (2991, 9)

# %%
# Double brackets used to specify the column as a dataframe and not a series
# converting the 'CategoryID' column in the Items_Assigned_Updated dataframe to numeric data type using the pd.to_numeric()
# use the apply column to apply the coversion to the entire column
Items_Assigned_Updated[['CategoryID']] = Items_Assigned_Updated[['CategoryID']].apply(pd.to_numeric)

# %%
Items_Assigned_Updated
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup Food Category
# 0        1.00     Kg                    MEAT           NaN
# 1        1.00     Kg                    MEAT           NaN
# 2        1.00     Kg                    MEAT           NaN
# 3     1000.00      g                    MEAT           NaN
# 4     1000.00      g                    MEAT           NaN
# ...       ...    ...                     ...           ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS           NaN
# 2987     1.00     CT  BAKING-RAW INGREDIENTS           NaN
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS           NaN
# 2989   225.00      g          FOOD - GROCERY           NaN
# 2990     1.00     lb                    MEAT           NaN
#
# [2991 rows x 9 columns]

# %%
path = os.path.join(os.getcwd(), "data", "mapping", "Items_List_Assigned.csv")
Items_Assigned_Updated.to_csv(path, index = False, header = True)

# %% [markdown]
# ## Mapping Items to Footprint Factors

# %%
Items_Assigned_Updated
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup Food Category
# 0        1.00     Kg                    MEAT           NaN
# 1        1.00     Kg                    MEAT           NaN
# 2        1.00     Kg                    MEAT           NaN
# 3     1000.00      g                    MEAT           NaN
# 4     1000.00      g                    MEAT           NaN
# ...       ...    ...                     ...           ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS           NaN
# 2987     1.00     CT  BAKING-RAW INGREDIENTS           NaN
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS           NaN
# 2989   225.00      g          FOOD - GROCERY           NaN
# 2990     1.00     lb                    MEAT           NaN
#
# [2991 rows x 9 columns]

# %%
# DEFINITION OF MAPPING: assigning certain attributes to data points based on criteria or predefined rules.

# Map GHG footprint factors
# merges two data frames Items_Assigned_Updated and ghge_factors on the columns CategoryID and Category ID, respectively. The 
# resulting data frame is stored in mapping.

# how='left' specifies that a left join is done between Items_Assigned_Updated and ghge_factors.
# left_on='CategoryID' specifies that the join condition for Items_Assigned_Updated should be based on the 'CategoryID' column.
# right_on='Category ID' specifies that the join condition for ghge_factors should be based on the 'Category ID' column.

mapping = pd.merge(Items_Assigned_Updated, ghge_factors.loc[:,['Category ID','Food Category','Active Total Supply Chain Emissions (kg CO2 / kg food)']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')
# if row in mapping has CategoryId == NaN then it assigns the value of the column Active Total Supply Chain Emissions (kg CO2 / kg food)
# to zero
for index in mapping.index:
    if np.isnan(mapping.loc[index,'Category ID']):
        mapping.loc[index,'Active Total Supply Chain Emissions (kg CO2 / kg food)'] = 0
# drops the columns Category ID and Food Category
display(mapping)
mapping = mapping.drop(columns=['Category ID', 'Food Category_x'])
mapping
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup Food Category_x  Category ID  \
# 0        1.00     Kg                    MEAT             NaN          1.0
# 1        1.00     Kg                    MEAT             NaN          1.0
# 2        1.00     Kg                    MEAT             NaN          1.0
# 3     1000.00      g                    MEAT             NaN          1.0
# 4     1000.00      g                    MEAT             NaN          1.0
# ...       ...    ...                     ...             ...          ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS             NaN         61.0
# 2987     1.00     CT  BAKING-RAW INGREDIENTS             NaN         61.0
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS             NaN         53.0
# 2989   225.00      g          FOOD - GROCERY             NaN         20.0
# 2990     1.00     lb                    MEAT             NaN         20.0
#
#           Food Category_y  \
# 0     beef & buffalo meat
# 1     beef & buffalo meat
# 2     beef & buffalo meat
# 3     beef & buffalo meat
# 4     beef & buffalo meat
# ...                   ...
# 2986     kitchen supplies
# 2987     kitchen supplies
# 2988               coffee
# 2989        soybeans/tofu
# 2990        soybeans/tofu
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)
# 0                                               41.3463
# 1                                               41.3463
# 2                                               41.3463
# 3                                               41.3463
# 4                                               41.3463
# ...                                                 ...
# 2986                                             0.0000
# 2987                                             0.0000
# 2988                                            16.6995
# 2989                                             1.7542
# 2990                                             1.7542
#
# [2991 rows x 12 columns]
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup      Food Category_y  \
# 0        1.00     Kg                    MEAT  beef & buffalo meat
# 1        1.00     Kg                    MEAT  beef & buffalo meat
# 2        1.00     Kg                    MEAT  beef & buffalo meat
# 3     1000.00      g                    MEAT  beef & buffalo meat
# 4     1000.00      g                    MEAT  beef & buffalo meat
# ...       ...    ...                     ...                  ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2987     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS               coffee
# 2989   225.00      g          FOOD - GROCERY        soybeans/tofu
# 2990     1.00     lb                    MEAT        soybeans/tofu
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)
# 0                                               41.3463
# 1                                               41.3463
# 2                                               41.3463
# 3                                               41.3463
# 4                                               41.3463
# ...                                                 ...
# 2986                                             0.0000
# 2987                                             0.0000
# 2988                                            16.6995
# 2989                                             1.7542
# 2990                                             1.7542
#
# [2991 rows x 10 columns]

# %%
# Map nitrogen footprint factors
mapping = pd.merge(mapping, nitro_factors.loc[:,['Category ID','Food Category','g N lost/kg product']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')

for index in mapping.index:
    if np.isnan(mapping.loc[index,'Category ID']):
        mapping.loc[index,'g N lost/kg product'] = 0

mapping = mapping.drop(columns=['Category ID', 'Food Category'])
mapping
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup      Food Category_y  \
# 0        1.00     Kg                    MEAT  beef & buffalo meat
# 1        1.00     Kg                    MEAT  beef & buffalo meat
# 2        1.00     Kg                    MEAT  beef & buffalo meat
# 3     1000.00      g                    MEAT  beef & buffalo meat
# 4     1000.00      g                    MEAT  beef & buffalo meat
# ...       ...    ...                     ...                  ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2987     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS               coffee
# 2989   225.00      g          FOOD - GROCERY        soybeans/tofu
# 2990     1.00     lb                    MEAT        soybeans/tofu
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               41.3463
# 1                                               41.3463
# 2                                               41.3463
# 3                                               41.3463
# 4                                               41.3463
# ...                                                 ...
# 2986                                             0.0000
# 2987                                             0.0000
# 2988                                            16.6995
# 2989                                             1.7542
# 2990                                             1.7542
#
#       g N lost/kg product
# 0                   329.5
# 1                   329.5
# 2                   329.5
# 3                   329.5
# 4                   329.5
# ...                   ...
# 2986                  0.0
# 2987                  0.0
# 2988                  2.7
# 2989                  5.9
# 2990                  5.9
#
# [2991 rows x 11 columns]

# %%
# Map land footprint factors
mapping = pd.merge(mapping, land_factors.loc[:,['Category ID','Food Category','Land Use (m^2)']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')

for index in mapping.index:
    if np.isnan(mapping.loc[index,'Category ID']):
        mapping.loc[index,'Land Use (m^2)'] = 0

mapping = mapping.drop(columns=['Category ID', 'Food Category'])
mapping
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup      Food Category_y  \
# 0        1.00     Kg                    MEAT  beef & buffalo meat
# 1        1.00     Kg                    MEAT  beef & buffalo meat
# 2        1.00     Kg                    MEAT  beef & buffalo meat
# 3     1000.00      g                    MEAT  beef & buffalo meat
# 4     1000.00      g                    MEAT  beef & buffalo meat
# ...       ...    ...                     ...                  ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2987     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS               coffee
# 2989   225.00      g          FOOD - GROCERY        soybeans/tofu
# 2990     1.00     lb                    MEAT        soybeans/tofu
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               41.3463
# 1                                               41.3463
# 2                                               41.3463
# 3                                               41.3463
# 4                                               41.3463
# ...                                                 ...
# 2986                                             0.0000
# 2987                                             0.0000
# 2988                                            16.6995
# 2989                                             1.7542
# 2990                                             1.7542
#
#       g N lost/kg product  Land Use (m^2)
# 0                   329.5         0.12645
# 1                   329.5         0.12645
# 2                   329.5         0.12645
# 3                   329.5         0.12645
# 4                   329.5         0.12645
# ...                   ...             ...
# 2986                  0.0         0.00000
# 2987                  0.0         0.00000
# 2988                  2.7         0.02162
# 2989                  5.9         0.00414
# 2990                  5.9         0.00414
#
# [2991 rows x 12 columns]

# %%
# Map water footprint factors
# mapping: DataFrame that is used to assign sustainability-related factors (greenhouse gas emissions, nitrogen loss, and 
# water footprint) to food items based on their category and other attributes. 
mapping = pd.merge(mapping, water_factors.loc[:,['Category ID','Food Category','Freshwater Withdrawals (L/FU)', 'Stress-Weighted Water Use (L/FU)']], 
                  how = 'left',
                  left_on = 'CategoryID', 
                  right_on = 'Category ID')

for index in mapping.index:
    if np.isnan(mapping.loc[index,'Category ID']):
        mapping.loc[index,'Freshwater Withdrawals (L/FU)'] = 0
        mapping.loc[index,'Stress-Weighted Water Use (L/FU)'] = 0

mapping = mapping.drop(columns=['Category ID', 'Food Category'])
mapping.drop_duplicates(subset=["ItemId"], inplace=True)
mapping
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup      Food Category_y  \
# 0        1.00     Kg                    MEAT  beef & buffalo meat
# 1        1.00     Kg                    MEAT  beef & buffalo meat
# 2        1.00     Kg                    MEAT  beef & buffalo meat
# 3     1000.00      g                    MEAT  beef & buffalo meat
# 4     1000.00      g                    MEAT  beef & buffalo meat
# ...       ...    ...                     ...                  ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2987     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS               coffee
# 2989   225.00      g          FOOD - GROCERY        soybeans/tofu
# 2990     1.00     lb                    MEAT        soybeans/tofu
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               41.3463
# 1                                               41.3463
# 2                                               41.3463
# 3                                               41.3463
# 4                                               41.3463
# ...                                                 ...
# 2986                                             0.0000
# 2987                                             0.0000
# 2988                                            16.6995
# 2989                                             1.7542
# 2990                                             1.7542
#
#       g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 0                   329.5         0.12645                         1677.2
# 1                   329.5         0.12645                         1677.2
# 2                   329.5         0.12645                         1677.2
# 3                   329.5         0.12645                         1677.2
# 4                   329.5         0.12645                         1677.2
# ...                   ...             ...                            ...
# 2986                  0.0         0.00000                            0.0
# 2987                  0.0         0.00000                            0.0
# 2988                  2.7         0.02162                           33.3
# 2989                  5.9         0.00414                            6.6
# 2990                  5.9         0.00414                            6.6
#
#       Stress-Weighted Water Use (L/FU)
# 0                              61309.0
# 1                              61309.0
# 2                              61309.0
# 3                              61309.0
# 4                              61309.0
# ...                                ...
# 2986                               0.0
# 2987                               0.0
# 2988                             340.7
# 2989                              32.4
# 2990                              32.4
#
# [2991 rows x 14 columns]

# %%
mapping[mapping["ItemId"] == "I-4524"]
# Out:
#       ItemId  CategoryID   Description  CaseQty CaseUOM  PakQty PakUOM  \
# 2006  I-4524        38.0  BEETS GOLDBC      5.0      lb     1.0     lb
#
#      InventoryGroup  Food Category_y  \
# 2006        PRODUCE  root vegetables
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 2006                                             0.3062
#
#       g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 2006                  7.9         0.00032                            9.9
#
#       Stress-Weighted Water Use (L/FU)
# 2006                              37.9

# %%
mapping["CategoryID"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Manully Adjust Footprint Factor for Specific Items

# %%
# For Manual_Factor: dataframe with items that adjusted GHGe factor manually.
# It takes the id for Manual_Factor for the index being iterated and if it is equal to item id of mapping dataframe then it sets
# the values of the columns to the manually adjusted values
# Note: the values for the columns in mapping DataFrame is adjusted and not Manual_Factor DataFrame
for index, row in Manual_Factor.iterrows():
    itemId = Manual_Factor.loc[index, 'ItemId']
    ghge = Manual_Factor.loc[index, 'Active Total Supply Chain Emissions (kg CO2 / kg food)']
    nitro = Manual_Factor.loc[index, 'g N lost/kg product']
    water = Manual_Factor.loc[index, 'Freshwater Withdrawals (L/FU)']
    land = Manual_Factor.loc[index, 'Land Use (m^2)']
    str_water = Manual_Factor.loc[index, 'Stress-Weighted Water Use (L/FU)']
    mapping.loc[mapping['ItemId'] == itemId, 'Active Total Supply Chain Emissions (kg CO2 / kg food)'] = ghge
    mapping.loc[mapping['ItemId'] == itemId, 'g N lost/kg product'] = nitro
    mapping.loc[mapping['ItemId'] == itemId, 'Freshwater Withdrawals (L/FU)'] = water
    mapping.loc[mapping['ItemId'] == itemId, 'Stress-Weighted Water Use (L/FU)'] = str_water
    mapping.loc[mapping['ItemId'] == itemId, 'Land Use (m^2)'] = land

# %%
mapping.drop_duplicates(subset = ['ItemId'], inplace=True)
mapping.dtypes
# Out:
# ItemId                                                     object
# CategoryID                                                float64
# Description                                                object
# CaseQty                                                   float64
# CaseUOM                                                    object
# PakQty                                                    float64
# PakUOM                                                     object
# InventoryGroup                                             object
# Food Category_y                                            object
# Active Total Supply Chain Emissions (kg CO2 / kg food)    float64
# g N lost/kg product                                       float64
# Land Use (m^2)                                            float64
# Freshwater Withdrawals (L/FU)                             float64
# Stress-Weighted Water Use (L/FU)                          float64
# dtype: object

# %%
mapping.shape
# Out:
# (2991, 14)

# %%
mapping
# Out:
#         ItemId  CategoryID               Description  CaseQty CaseUOM  \
# 0      I-57545         1.0   CHUCK FLAT BONELESS FZN     3.30      Kg
# 1      I-10869         1.0       BEEF STIRFRY COV FR     5.00      Kg
# 2       I-7064         1.0     BEEF OUTSIDE FLAT AAA     1.00      Kg
# 3      I-37005         1.0            BEEF MEATBALLS     4.54      Kg
# 4      I-37002         1.0  BEEF INSIDE ROUND SHAVED     9.00      Kg
# ...        ...         ...                       ...      ...     ...
# 2986   I-1119p        61.0         WRAP FOIL 18X1000     1.00      CT
# 2987   I-1126p        61.0         WRAP FOIL 24X1000     1.00      CT
# 2988    I-1484        53.0          FLAVOURS COFFEE      4.00       L
# 2989   I-72206        20.0      TOFU JUST SMOKE BULK     8.00     pak
# 2990  I-102947        20.0         WAGYU UMAMI*STRIP     1.00      lb
#
#        PakQty PakUOM          InventoryGroup      Food Category_y  \
# 0        1.00     Kg                    MEAT  beef & buffalo meat
# 1        1.00     Kg                    MEAT  beef & buffalo meat
# 2        1.00     Kg                    MEAT  beef & buffalo meat
# 3     1000.00      g                    MEAT  beef & buffalo meat
# 4     1000.00      g                    MEAT  beef & buffalo meat
# ...       ...    ...                     ...                  ...
# 2986     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2987     1.00     CT  BAKING-RAW INGREDIENTS     kitchen supplies
# 2988     2.41     Kg  BAKING-RAW INGREDIENTS               coffee
# 2989   225.00      g          FOOD - GROCERY        soybeans/tofu
# 2990     1.00     lb                    MEAT        soybeans/tofu
#
#       Active Total Supply Chain Emissions (kg CO2 / kg food)  \
# 0                                               41.3463
# 1                                               41.3463
# 2                                               41.3463
# 3                                               41.3463
# 4                                               41.3463
# ...                                                 ...
# 2986                                             0.0000
# 2987                                             0.0000
# 2988                                            16.6995
# 2989                                             1.7542
# 2990                                             1.7542
#
#       g N lost/kg product  Land Use (m^2)  Freshwater Withdrawals (L/FU)  \
# 0                   329.5         0.12645                         1677.2
# 1                   329.5         0.12645                         1677.2
# 2                   329.5         0.12645                         1677.2
# 3                   329.5         0.12645                         1677.2
# 4                   329.5         0.12645                         1677.2
# ...                   ...             ...                            ...
# 2986                  0.0         0.00000                            0.0
# 2987                  0.0         0.00000                            0.0
# 2988                  2.7         0.02162                           33.3
# 2989                  5.9         0.00414                            6.6
# 2990                  5.9         0.00414                            6.6
#
#       Stress-Weighted Water Use (L/FU)
# 0                              61309.0
# 1                              61309.0
# 2                              61309.0
# 3                              61309.0
# 4                              61309.0
# ...                                ...
# 2986                               0.0
# 2987                               0.0
# 2988                             340.7
# 2989                              32.4
# 2990                              32.4
#
# [2991 rows x 14 columns]

# %%
ingredients = pd.read_csv("data/preprocessed/Ingredients_List.csv")
ingredients
# Out:
#      IngredientId   Qty Uom  Conversion  InvFactor   Recipe
# 0          P-9857   5.0  Kg       1.000     1.1111  P-10112
# 1         P-48933   1.0  Kg       1.000     1.0000  P-10113
# 2          I-4626  16.0  CT       1.000     2.6667  P-10115
# 3          P-9755   1.0  lb       1.000     1.0000  P-10119
# 4         P-18746   1.0  Kg       1.000     1.0000  P-10241
# ...           ...   ...  ..         ...        ...      ...
# 5492      I-22493   5.0   g       0.001     1.0000  R-73668
# 5493      P-26514   2.0   g       1.000     1.0000  R-73668
# 5494      P-44913  90.0   g       0.001     1.0000  R-73668
# 5495      P-50725   1.0  ea       1.000     1.0000  R-73668
# 5496      P-73667  25.0  ml       0.001     1.0000  R-73668
#
# [5497 rows x 6 columns]

# %%
map_list = mapping["ItemId"].unique()
absent_list = []

for item in ingredients["IngredientId"].unique():
    if item not in map_list and item.startswith("I-"):
        absent_list.append(item)

# absent_list contains the IngredientIds that are not present in mapping but are present in the ingredients DataFrame
print(absent_list)
# Out:
# []

# %%
# Converts mapping DataFrame to the Mapping.csv file
path = os.path.join(os.getcwd(), "data", "mapping", "Mapping.csv")
mapping.to_csv(path, index = False, header = True)
