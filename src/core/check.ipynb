# %%
import os
import glob
import calculator
import labeller

os.chdir("../..")
filepath_list = glob.glob(os.path.join(os.getcwd(), "data", "raw", "Gather", "*.oc"))
print(filepath_list)
labeller_obj = labeller.Labeller(filepath_list, "Gather")
labeller_obj.ingredients
# Out:
# ['/Users/vivaanwadhwa/Documents/GitHub/CFFS/data/raw/Gather/ALL_gather_menu_july30.oc', '/Users/vivaanwadhwa/Documents/GitHub/CFFS/data/raw/Gather/missing_gather_items_15_july.oc', '/Users/vivaanwadhwa/Documents/GitHub/CFFS/data/raw/Gather/Gather_missing_items.oc.oc']
#       ItemId              Description CaseQty CaseUOM    PakQty PakUOM  \
# 0     I-7631           5 SPICE POWDER   1.000      ea     1.000     lb
# 1    I-43851               AJWAIN 5LB   5.000      lb   454.000      g
# 2     I-3617  ALLSPICE GROUND SHAKER    8.000    each   454.000      g
# 3     I-1852    ALMOND BEV - ORIGINAL  24.000      CT     1.000     CT
# 4    I-44059           ALMOND BUTTER*  10.000      Kg     1.000     Kg
# ..       ...                      ...     ...     ...       ...    ...
# 872  I-17159      TOMATOES GRAPE 10LB  10.000      lb     1.000     lb
# 873   I-4933         TOMATOES ROMA MX  25.000      lb     1.000     lb
# ...
